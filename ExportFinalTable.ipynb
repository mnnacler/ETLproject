# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:postgres@localhost:5432/ETL")

# %%
Base = automap_base()

# %%
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['finaltable']

# %%
final = Base.classes.finaltable

session = Session(engine)

# %%
import pandas as pd

# %%
finaltable = engine.execute("select * from finalTable").fetchall()
finaltable
headers = ['Film', 'Oscar Wins', 'Netflix ID', 'Director', 'Cast', 'Country', 'Data Added', 'Release Year', 'Rating', 'Duration', 'Category', 'Description', 'Rank in Year', 'IMDB Rating', 'Budget', 'Domestic Distributor', 'Worldwide Gross', 'Domestic Gross']
finalDF = pd.DataFrame(finaltable, columns = headers)
finalDF
# Out:
#                                              Film  Oscar Wins  Netflix ID  \
# 0                                      The Matrix           4    20557937
# 1                                 American Beauty           5    60000407
# 2           The Lord of the Rings: The Two Towers           2    60004483
# 3                              The Little Mermaid           2    80166319
# 4                                        Rain Man           4    60029369
# 5                                       Inception           4    70131314
# 6   The Lord of the Rings: The Return of the King          11    60004484
# 7                                          Tarzan           1    26009364
# 8                                           Joker           2    70219529
# 9                                          Arthur           2    70167072
# 10                                   Philadelphia           2      855084
# 11                                  Black Panther           3    80201906
# ...

# %%
finalDF.to_csv("finalTable.csv")
